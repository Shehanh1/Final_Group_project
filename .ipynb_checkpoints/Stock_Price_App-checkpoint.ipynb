# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import pandas as pd
import plotly.graph_objs as go
from dash.dependencies import Input, Output
from keras.models import load_model
from sklearn.preprocessing import MinMaxScaler
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/kq/z9bqrgmn3kn0h8vj6sy1cjvc0000gn/T/ipykernel_1081/1229918661.py in <module>
# ----> 1 import dash
#       2 import dash_core_components as dcc
#       3 import dash_html_components as html
#       4 import pandas as pd
#       5 import plotly.graph_objs as go
#
# /opt/anaconda3/lib/python3.8/site-packages/dash/__init__.py in <module>
#       3 # must come before any other imports.
#       4 __plotly_dash = True
# ----> 5 from .dash import Dash, no_update  # noqa: F401,E402
#       6 from .dependencies import (  # noqa: F401,E402
#       7     Input,  # noqa: F401,E402
#
# /opt/anaconda3/lib/python3.8/site-packages/dash/dash.py in <module>
#      15
#      16 import flask
# ---> 17 from flask_compress import Compress
#      18 from werkzeug.debug.tbtools import get_current_traceback
#      19 from pkg_resources import get_distribution, parse_version
#
# /opt/anaconda3/lib/python3.8/site-packages/flask_compress/__init__.py in <module>
# ----> 1 from .flask_compress import Compress
#       2
#       3 # _version.py is generated by setuptools_scm when building the package, it is not versioned.
#       4 # If missing, this means that the imported code was most likely the git repository, that was
#       5 # installed without the "editable" mode.
#
# /opt/anaconda3/lib/python3.8/site-packages/flask_compress/flask_compress.py in <module>
#      12 from collections import defaultdict
#      13
# ---> 14 import brotli
#      15 from flask import request, after_this_request, current_app
#      16
#
# /opt/anaconda3/lib/python3.8/site-packages/brotli/__init__.py in <module>
#       1 # -*- coding: utf-8 -*-
#       2 # flake8: noqa
# ----> 3 from .brotli import (
#       4     decompress, Decompressor, compress, BrotliEncoderMode, DEFAULT_MODE,
#       5     Compressor, MODE_GENERIC, MODE_TEXT, MODE_FONT, error, Error
#
# /opt/anaconda3/lib/python3.8/site-packages/brotli/brotli.py in <module>
#       3 import enum
#       4
# ----> 5 from ._brotli import ffi, lib
#       6
#       7
#
# ImportError: dlopen(/opt/anaconda3/lib/python3.8/site-packages/_cffi_backend.cpython-38-darwin.so, 2): Library not loaded: @rpath/libffi.7.dylib
#   Referenced from: /opt/anaconda3/lib/python3.8/site-packages/_cffi_backend.cpython-38-darwin.so
#   Reason: image not found
